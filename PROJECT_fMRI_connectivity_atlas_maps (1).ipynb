# %% [markdown]
# # For the BrainHack course project - fMRI connectivity matrix mapping

# %%
#The sleepy group

# %%
# !pip install nilearn
# Out:
# Requirement already satisfied: nilearn in /Users/Gaithtry/fsl/lib/python3.12/site-packages (0.13.1)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (1.5.2)
# Requirement already satisfied: nibabel>=5.2.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (5.3.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (2.1.3)
# Requirement already satisfied: packaging in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (25.0)
# Requirement already satisfied: pandas>=2.2.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (2.3.3)
# Requirement already satisfied: requests>=2.30.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (2.32.5)
# Requirement already satisfied: scikit-learn>=1.4.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (1.5.2)
# Requirement already satisfied: scipy>=1.9.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nilearn) (1.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from jinja2>=3.1.2->nilearn) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from nibabel>=5.2.0->nilearn) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from requests>=2.30.0->nilearn) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from requests>=2.30.0->nilearn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from requests>=2.30.0->nilearn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from requests>=2.30.0->nilearn) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from nilearn import image, plotting
from nilearn.maskers import NiftiMapsMasker, NiftiLabelsMasker
from nilearn.connectome import ConnectivityMeasure
from nilearn import datasets

# %%
from pathlib import Path
# Set this to path of where dataset is stored
dataset_root = Path("/Users/Gaithtry/Downloads/brain_hack/data_files/rest_sleep_processed")

func_file = dataset_root / "sub-01_task-rest_run-1_processed.nii.gz"

print("Using:", func_file)
# Out:
# Using: /Users/Gaithtry/Downloads/brain_hack/data_files/rest_sleep_processed/sub-01_task-rest_run-1_processed.nii.gz

# %%
### Shaefer Atals
atlas_dataset = datasets.fetch_atlas_schaefer_2018(data_dir=dataset_root, n_rois=400, yeo_networks=7)
atlas_filepath = atlas_dataset.maps
atlas_labels = atlas_dataset.labels[1:]

atlas_masker = NiftiLabelsMasker(
    labels_img=atlas_dataset.maps,
    standardize=True, # Z-scores the time series
    detrend=True,
    #high_pass=0.009, low_pass=0.08, t_r=2.1 # Adjust TR to your data
)

atlas_masker.fit()
# Out:
# [fetch_atlas_schaefer_2018] Dataset found in
# /Users/Gaithtry/Downloads/brain_hack/data_files/rest_sleep_processed/schaefer_2018
# NiftiLabelsMasker(detrend=True,
#                   labels_img='/Users/Gaithtry/Downloads/brain_hack/data_files/rest_sleep_processed/schaefer_2018/Schaefer2018_400Parcels_7Networks_order_FSLMNI152_1mm.nii.gz',
#                   standardize=True)

# %%
correlation_measure = ConnectivityMeasure(kind="correlation")

def compute_connectivity(func_file):
    fmri_img = image.load_img(func_file)
    timeseries = atlas_masker.transform(fmri_img)
    matrix = correlation_measure.fit_transform([timeseries])[0]
    
    return timeseries, matrix

# %%
def plot_connectivity_matrix(matrix, labels, title="Connectivity Matrix"):
    fig, ax = plt.subplots(figsize=(12, 10))
    im = ax.imshow(matrix, vmin=-1, vmax=1, cmap="RdBu_r")
    ax.set_xticks(range(len(labels)))
    ax.set_yticks(range(len(labels)))
    ax.set_xticklabels(labels, rotation=90, fontsize=7)
    ax.set_yticklabels(labels, fontsize=7)
    plt.colorbar(im, ax=ax, label="Pearson r")
    ax.set_title(title)
    plt.tight_layout()
    plt.show()

# %%
timeseries, matrix = compute_connectivity(func_file)
# Out:
# /var/folders/fs/j7mzyn0108nf8c8x6ny97trc0000gq/T/ipykernel_9031/1265877012.py:5: FutureWarning: The 'zscore' strategy incorrectly uses population std to calculate sample zscores. The new strategy 'zscore_sample' corrects this behavior by using the sample std. In release 0.14.0, the 'zscore' option will be removed and using standardize=True will fall back to 'zscore_sample'.To avoid this warning, please use 'zscore_sample' instead.
#   timeseries = atlas_masker.transform(fmri_img)
# /var/folders/fs/j7mzyn0108nf8c8x6ny97trc0000gq/T/ipykernel_9031/1265877012.py:5: UserWarning: Resampling labels at transform time...
# To avoid this warning, make sure to pass the images you want to transform to fit() first, or directly use fit_transform().
#   timeseries = atlas_masker.transform(fmri_img)
# /var/folders/fs/j7mzyn0108nf8c8x6ny97trc0000gq/T/ipykernel_9031/1265877012.py:6: FutureWarning: The default strategy for standardize is currently 'zscore' which incorrectly uses population std to calculate sample zscores. The new strategy 'zscore_sample' corrects this behavior by using the sample std. In release 0.14.0, the default strategy will be replaced by the new strategy, the 'zscore' option will be removed. and using standardize=True will fall back to 'zscore_sample'.To avoid this warning, please use 'zscore_sample' instead.
#   matrix = correlation_measure.fit_transform([timeseries])[0]

# %%
#plotting the atlas labels

import matplotlib.pyplot as plt
import numpy as np
from nilearn import plotting
from itertools import groupby

network_assignments = [label.decode('utf-8').split('_')[2] if isinstance(label, bytes) else label.split('_')[2] for label in atlas_labels]
sort_idx = np.argsort(network_assignments)

ordered_matrix = matrix[sort_idx, :][:, sort_idx]
ordered_labels = [network_assignments[i] for i in sort_idx]

#count and summarize labels for axis purposes
unique_networks = []
network_sizes = []
for k, g in groupby(ordered_labels):
    unique_networks.append(k)
    network_sizes.append(sum(1 for _ in list(g)))

#establish label boundaries 
boundaries = np.insert(np.cumsum(network_sizes), 0, 0)
tick_positions = [(boundaries[i] + boundaries[i+1]) / 2 for i in range(len(boundaries) - 1)]

#plot matrix
display = plotting.plot_matrix(
    ordered_matrix,
    figure=(10, 10),
    colorbar=True,
    reorder=False
)

#matrix axes
ax = display.axes

# boundary lines inside axis
colors = plt.cm.Set2(np.linspace(0, 1, len(network_sizes)))
for i in range(1, len(boundaries) - 1):
    ax.axvline(boundaries[i] - 0.5, color="black", linewidth=0.5, alpha=0.9)
    ax.axhline(boundaries[i] - 0.5, color="black", linewidth=0.5, alpha=0.9)
    
bar_width = 15 
matrix_size = ordered_matrix.shape[0]

# colored bars along the edges
for i in range(len(boundaries) - 1):
    start, end = boundaries[i], boundaries[i+1]
    current_color = colors[i]
    
    # Left edge color bar (Y-axis tracking)
    ax.axhspan(start - 0.5, end - 0.5, xmin=-bar_width/matrix_size, xmax=0, 
               color=current_color, clip_on=False, zorder=3)
    
    # Bottom edge color bar (X-axis tracking)
    ax.axvspan(start - 0.5, end - 0.5, ymin=-bar_width/matrix_size, ymax=0, 
               color=current_color, clip_on=False, zorder=3)

ax.tick_params(axis='both', which='both', length=18, pad=10, direction='out')

# labels 
ax.set_xticks(tick_positions)
ax.set_xticklabels(unique_networks, rotation=90, fontsize=10)

ax.set_yticks(tick_positions)
ax.set_yticklabels(unique_networks, fontsize=10)

plt.show()

# %%
print(atlas_labels[:10])
# Out:
# ['7Networks_LH_Vis_1', '7Networks_LH_Vis_2', '7Networks_LH_Vis_3', '7Networks_LH_Vis_4', '7Networks_LH_Vis_5', '7Networks_LH_Vis_6', '7Networks_LH_Vis_7', '7Networks_LH_Vis_8', '7Networks_LH_Vis_9', '7Networks_LH_Vis_10']

# %%
print(matrix)
# Out:
# [[ 1.          0.7829907   0.63687354 ...  0.1781557   0.09178053
#    0.14872544]
#  [ 0.7829907   1.          0.49129567 ... -0.02197398  0.03932394
#    0.15197612]
#  [ 0.63687354  0.49129567  1.         ...  0.27446797  0.08395804
#    0.19654243]
#  ...
#  [ 0.1781557  -0.02197398  0.27446797 ...  1.          0.5328687
#    0.5429166 ]
#  [ 0.09178053  0.03932394  0.08395804 ...  0.5328687   1.
#    0.7166484 ]
#  [ 0.14872544  0.15197612  0.19654243 ...  0.5429166   0.7166484
#    1.        ]]

# %%
print(unique_networks)
# Out:
# ['Cont', 'Default', 'DorsAttn', 'Limbic', 'SalVentAttn', 'SomMot', 'Vis']

# %%
# !pip install pycirclize
# Out:
# Requirement already satisfied: pycirclize in /Users/Gaithtry/fsl/lib/python3.12/site-packages (1.10.1)
# Requirement already satisfied: biopython>=1.80 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pycirclize) (1.87)
# Requirement already satisfied: matplotlib>=3.6.3 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pycirclize) (3.9.4)
# Requirement already satisfied: numpy>=1.21 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pycirclize) (2.1.3)
# Requirement already satisfied: pandas>=1.3.5 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pycirclize) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from matplotlib>=3.6.3->pycirclize) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pandas>=1.3.5->pycirclize) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from pandas>=1.3.5->pycirclize) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Gaithtry/fsl/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.3->pycirclize) (1.17.0)

# %%
#creating a 7 by 7 matrix from the 400 by 400 matrix:

import numpy as np
import pandas as pd
from itertools import groupby

n_networks = len(unique_networks)
network_matrix = np.zeros((n_networks, n_networks))

for i in range(n_networks):
    for j in range(n_networks):
        row_start, row_end = boundaries[i], boundaries[i+1]
        col_start, col_end = boundaries[j], boundaries[j+1]
        block = ordered_matrix[row_start:row_end, col_start:col_end]
        network_matrix[i, j] = np.mean(block)

network_df = pd.DataFrame(
    network_matrix,
    index=unique_networks,
    columns=unique_networks
)

print(network_df)
# Out:
#                  Cont   Default  DorsAttn    Limbic  SalVentAttn    SomMot  \
# Cont         0.467825  0.318164  0.336001  0.258523     0.307480  0.366738
# Default      0.318164  0.406766  0.270735  0.270343     0.304995  0.381493
# DorsAttn     0.336001  0.270735  0.383026  0.246808     0.312052  0.376357
# Limbic       0.258523  0.270343  0.246808  0.339024     0.242048  0.295647
# SalVentAttn  0.307480  0.304995  0.312052  0.242048     0.426609  0.437299
# SomMot       0.366738  0.381493  0.376357  0.295647     0.437299  0.589484
# Vis          0.238382  0.273088  0.310070  0.273504     0.292469  0.373374
#
#                   Vis
# Cont         0.238382
# Default      0.273088
# DorsAttn     0.310070
# Limbic       0.273504
# SalVentAttn  0.292469
# SomMot       0.373374
# Vis          0.472262

# %%
#plotting the atlas labels - 7 by 7 
import matplotlib.pyplot as plt
import numpy as np
from nilearn import plotting

display_matrix = network_matrix.copy()

display = plotting.plot_matrix(
    display_matrix,
    figure=(10, 10),
    colorbar=True,
    reorder=False,
    vmin=-0.8,
    vmax=0.8
)

ax = display.axes
n = len(unique_networks)

# Boundary lines 
colors = plt.cm.Set2(np.linspace(0, 1, n))
for i in range(1, n):
    ax.axvline(i - 0.5, color="black", linewidth=0.5, alpha=0.9)
    ax.axhline(i - 0.5, color="black", linewidth=0.5, alpha=0.9)

# Colored edge bars — bar_width scaled to 7x7 equivalent of original's 15/400
bar_width = 0.2
matrix_size = n  # now 7, not 400

for i in range(n):
    start, end = i - 0.5, i + 0.5
    current_color = colors[i]

    # Left edge bar (Y-axis)
    ax.axhspan(start, end, xmin=-bar_width/matrix_size, xmax=0,
               color=current_color, clip_on=False, zorder=3)

    # Bottom edge bar (X-axis)
    ax.axvspan(start, end, ymin=-bar_width/matrix_size, ymax=0,
               color=current_color, clip_on=False, zorder=3)

# Ticks — direct integer positions since one cell = one network
ax.tick_params(axis='both', which='both', length=18, pad=10, direction='out')
ax.set_xticks(range(n))
ax.set_xticklabels(unique_networks, rotation=90, fontsize=10)
ax.set_yticks(range(n))
ax.set_yticklabels(unique_networks, fontsize=10)

plt.show()

# %%
#testing out the chord diagram

from pycirclize import Circos
import pandas as pd


circos = Circos.chord_diagram(
    network_df, 
    space=0, 
    cmap="tab10", 
    label_kws=dict(size=12), 
    link_kws=dict(ec="black", lw=0.5)
)


# 4. Display or save the figure
fig = circos.plotfig()
circos.savefig("chord_diagram.png")
